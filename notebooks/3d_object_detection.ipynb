# %%
# !ls
# Out:
# Desktop    Music     Templates	     bin	    examples.desktop
# Documents  Pictures  Untitled.ipynb  cuda-10.0	    google-research
# Downloads  Public    Videos	     docker-python  tf3d_env

# %%
# !hostname
# Out:
# 67ed82f5eaef

# %% [markdown]
# ## Testing Jupyter Notebook

# %%
import tensorflow as tf

# %%
# !whoami
# Out:
# root

# %%
print(tf.__version__)
# Out:
# 2.2.0
